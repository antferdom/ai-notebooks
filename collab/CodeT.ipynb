# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd ./drive/MyDrive/github
# Out:
# /content/drive/MyDrive/github

# %%
# !git clone https://github.com/microsoft/CodeT.git
# Out:
# Cloning into 'CodeT'...
# remote: Enumerating objects: 105, done.
# remote: Counting objects: 100% (105/105), done.
# remote: Compressing objects: 100% (86/86), done.
# remote: Total 105 (delta 21), reused 75 (delta 13), pack-reused 0
# Receiving objects: 100% (105/105), 27.09 MiB | 8.10 MiB/s, done.
# Resolving deltas: 100% (21/21), done.
# Checking out files: 100% (45/45), done.

# %% [markdown]
# # Prepare Environment

# %% [markdown]
# Build the system. Installing dependencies (not properly setup)

# %%
# !pip install numpy
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %% [markdown]
# # Prepare Data

# %%
# %cd CodeT
# Out:
# /content/drive/MyDrive/github/CodeT

# %% [markdown]
# # Use CodeT

# %% [markdown]
# You may use the script `main.py` to run CodeT, which automatically performs post-processing, dual execution agreement, and `pass@k` **evaluation**. Before running the script, you need to specify several arguments:

# %% [markdown]
# ```shell
# $python main.py
#     --source_path_for_solution PATH_1 # model input file in .jsonl format
#     --predict_path_for_solution PATH_2 # model output file in .jsonl format
#     --source_path_for_test PATH_3 # model input file in .jsonl format
#     --predict_path_for_test PATH_4 # model output file in .jsonl format
#     --cache_dir PATH_5 # the directory to store the cache files (execution results)
#     --timeout NUMBER # how many seconds to wait during execution for each test case (default 0.1)
#     --test_case_limit NUMBER # first n test cases per sample (default 5)
# ```

# %% [markdown]
# **main.py arguments:**
# 1. `source_path_for_solution`: Model input file in _.json_ format.
# 2. `predict_path_for_solution`: Model output file in _.json_ format.
# 3. `source_path_for_test`: Model input file in _.json_ format.
# 4. `predict_path_for_test`: Model output file in _.json_ format.
# 5. `cache_dir`: Directory to store the cache file (**execution results**)
# 6. `timeout`: How many seconds to wait during execution for each test case (**default** = 0.1)
# 7. `test_case_limit`: First **n** test cases per sample (**default** = 5)
