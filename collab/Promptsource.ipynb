# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd ./drive/MyDrive/github
# Out:
# /content/drive/MyDrive/github

# %%
# !git clone https://github.com/bigscience-workshop/promptsource.git
# Out:
# fatal: destination path 'promptsource' already exists and is not an empty directory.

# %%
# %cd promptsource
# Out:
# /content/drive/MyDrive/github/promptsource

# %%
# !pip install -e .
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Obtaining file:///content/drive/MyDrive/github/promptsource
# Collecting black<=21.12b0
#   Downloading black-21.12b0-py3-none-any.whl (156 kB)
#      |████████████████████████████████| 156 kB 5.3 MB/s
# Collecting datasets>=1.7.0
#   Downloading datasets-2.4.0-py3-none-any.whl (365 kB)
#      |████████████████████████████████| 365 kB 29.8 MB/s
# Collecting flake8
#   Downloading flake8-5.0.4-py2.py3-none-any.whl (61 kB)
#      |████████████████████████████████| 61 kB 505 kB/s
# Collecting isort==5.8.0
#   Downloading isort-5.8.0-py3-none-any.whl (103 kB)
#      |████████████████████████████████| 103 kB 51.8 MB/s
# Requirement already satisfied: pytest in /usr/local/lib/python3.7/dist-packages (from promptsource==0.2.3) (3.6.4)
# Collecting pyyaml>=5
#   Downloading PyYAML-6.0-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (596 kB)
#      |████████████████████████████████| 596 kB 26.0 MB/s
# Collecting streamlit==0.82
#   Downloading streamlit-0.82.0-py2.py3-none-any.whl (8.2 MB)
#      |████████████████████████████████| 8.2 MB 53.9 MB/s
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.7/dist-packages (from promptsource==0.2.3) (2.11.3)
# Requirement already satisfied: plotly in /usr/local/lib/python3.7/dist-packages (from promptsource==0.2.3) (5.5.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from promptsource==0.2.3) (2.23.0)
# Requirement already satisfied: pandas in /usr/local/lib/python3.7/dist-packages (from promptsource==0.2.3) (1.3.5)
# Collecting py7zr
#   Downloading py7zr-0.20.0-py3-none-any.whl (64 kB)
#      |████████████████████████████████| 64 kB 3.5 MB/s
# Requirement already satisfied: tornado>=5.0 in /usr/local/lib/python3.7/dist-packages (from streamlit==0.82->promptsource==0.2.3) (5.1.1)
# Requirement already satisfied: tzlocal in /usr/local/lib/python3.7/dist-packages (from streamlit==0.82->promptsource==0.2.3) (1.5.1)
# Requirement already satisfied: protobuf!=3.11,>=3.6.0 in /usr/local/lib/python3.7/dist-packages (from streamlit==0.82->promptsource==0.2.3) (3.17.3)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.7/dist-packages (from streamlit==0.82->promptsource==0.2.3) (7.1.2)
# Collecting watchdog
#   Downloading watchdog-2.1.9-py3-none-manylinux2014_x86_64.whl (78 kB)
#      |████████████████████████████████| 78 kB 7.2 MB/s
# Collecting validators
#   Downloading validators-0.20.0.tar.gz (30 kB)
# Collecting gitpython
#   Downloading GitPython-3.1.27-py3-none-any.whl (181 kB)
#      |████████████████████████████████| 181 kB 54.3 MB/s
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.7/dist-packages (from streamlit==0.82->promptsource==0.2.3) (2.8.2)
# Requirement already satisfied: cachetools>=4.0 in /usr/local/lib/python3.7/dist-packages (from streamlit==0.82->promptsource==0.2.3) (4.2.4)
# Requirement already satisfied: astor in /usr/local/lib/python3.7/dist-packages (from streamlit==0.82->promptsource==0.2.3) (0.8.1)
# Requirement already satisfied: toml in /usr/local/lib/python3.7/dist-packages (from streamlit==0.82->promptsource==0.2.3) (0.10.2)
# Collecting blinker
#   Downloading blinker-1.5-py2.py3-none-any.whl (12 kB)
# Collecting base58
#   Downloading base58-2.1.1-py3-none-any.whl (5.6 kB)
# Requirement already satisfied: pyarrow in /usr/local/lib/python3.7/dist-packages (from streamlit==0.82->promptsource==0.2.3) (6.0.1)
# Requirement already satisfied: altair>=3.2.0 in /usr/local/lib/python3.7/dist-packages (from streamlit==0.82->promptsource==0.2.3) (4.2.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/dist-packages (from streamlit==0.82->promptsource==0.2.3) (21.3)
# Collecting pydeck>=0.1.dev5
#   Downloading pydeck-0.7.1-py2.py3-none-any.whl (4.3 MB)
#      |████████████████████████████████| 4.3 MB 35.2 MB/s
# Requirement already satisfied: click<8.0,>=7.0 in /usr/local/lib/python3.7/dist-packages (from streamlit==0.82->promptsource==0.2.3) (7.1.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from streamlit==0.82->promptsource==0.2.3) (1.21.6)
# Requirement already satisfied: entrypoints in /usr/local/lib/python3.7/dist-packages (from altair>=3.2.0->streamlit==0.82->promptsource==0.2.3) (0.4)
# Requirement already satisfied: toolz in /usr/local/lib/python3.7/dist-packages (from altair>=3.2.0->streamlit==0.82->promptsource==0.2.3) (0.12.0)
# Requirement already satisfied: jsonschema>=3.0 in /usr/local/lib/python3.7/dist-packages (from altair>=3.2.0->streamlit==0.82->promptsource==0.2.3) (4.3.3)
# Collecting typed-ast>=1.4.2
#   Downloading typed_ast-1.5.4-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (843 kB)
#      |████████████████████████████████| 843 kB 57.2 MB/s
# Collecting platformdirs>=2
#   Downloading platformdirs-2.5.2-py3-none-any.whl (14 kB)
# Collecting tomli<2.0.0,>=0.2.6
#   Downloading tomli-1.2.3-py3-none-any.whl (12 kB)
# Requirement already satisfied: typing-extensions>=3.10.0.0 in /usr/local/lib/python3.7/dist-packages (from black<=21.12b0->promptsource==0.2.3) (4.1.1)
# Collecting pathspec<1,>=0.9.0
#   Downloading pathspec-0.9.0-py2.py3-none-any.whl (31 kB)
# Collecting mypy-extensions>=0.4.3
#   Downloading mypy_extensions-0.4.3-py2.py3-none-any.whl (4.5 kB)
# Collecting huggingface-hub<1.0.0,>=0.1.0
#   Downloading huggingface_hub-0.8.1-py3-none-any.whl (101 kB)
#      |████████████████████████████████| 101 kB 11.9 MB/s
# Collecting fsspec[http]>=2021.11.1
#   Downloading fsspec-2022.7.1-py3-none-any.whl (141 kB)
#      |████████████████████████████████| 141 kB 57.9 MB/s
# Requirement already satisfied: tqdm>=4.62.1 in /usr/local/lib/python3.7/dist-packages (from datasets>=1.7.0->promptsource==0.2.3) (4.64.0)
# Collecting multiprocess
#   Downloading multiprocess-0.70.13-py37-none-any.whl (115 kB)
#      |████████████████████████████████| 115 kB 46.6 MB/s
# Collecting xxhash
#   Downloading xxhash-3.0.0-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (212 kB)
#      |████████████████████████████████| 212 kB 56.1 MB/s
# Requirement already satisfied: dill<0.3.6 in /usr/local/lib/python3.7/dist-packages (from datasets>=1.7.0->promptsource==0.2.3) (0.3.5.1)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.7/dist-packages (from datasets>=1.7.0->promptsource==0.2.3) (3.8.1)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from datasets>=1.7.0->promptsource==0.2.3) (4.12.0)
# Collecting responses<0.19
#   Downloading responses-0.18.0-py3-none-any.whl (38 kB)
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from huggingface-hub<1.0.0,>=0.1.0->datasets>=1.7.0->promptsource==0.2.3) (3.8.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /usr/local/lib/python3.7/dist-packages (from jsonschema>=3.0->altair>=3.2.0->streamlit==0.82->promptsource==0.2.3) (0.18.1)
# Requirement already satisfied: attrs>=17.4.0 in /usr/local/lib/python3.7/dist-packages (from jsonschema>=3.0->altair>=3.2.0->streamlit==0.82->promptsource==0.2.3) (22.1.0)
# Requirement already satisfied: importlib-resources>=1.4.0 in /usr/local/lib/python3.7/dist-packages (from jsonschema>=3.0->altair>=3.2.0->streamlit==0.82->promptsource==0.2.3) (5.9.0)
# Requirement already satisfied: zipp>=3.1.0 in /usr/local/lib/python3.7/dist-packages (from importlib-resources>=1.4.0->jsonschema>=3.0->altair>=3.2.0->streamlit==0.82->promptsource==0.2.3) (3.8.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging->streamlit==0.82->promptsource==0.2.3) (3.0.9)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas->promptsource==0.2.3) (2022.1)
# Requirement already satisfied: six>=1.9 in /usr/local/lib/python3.7/dist-packages (from protobuf!=3.11,>=3.6.0->streamlit==0.82->promptsource==0.2.3) (1.15.0)
# Requirement already satisfied: ipywidgets>=7.0.0 in /usr/local/lib/python3.7/dist-packages (from pydeck>=0.1.dev5->streamlit==0.82->promptsource==0.2.3) (7.7.1)
# Requirement already satisfied: traitlets>=4.3.2 in /usr/local/lib/python3.7/dist-packages (from pydeck>=0.1.dev5->streamlit==0.82->promptsource==0.2.3) (5.1.1)
# Requirement already satisfied: ipykernel>=5.1.2 in /usr/local/lib/python3.7/dist-packages (from pydeck>=0.1.dev5->streamlit==0.82->promptsource==0.2.3) (5.3.4)
# Requirement already satisfied: ipython>=5.0.0 in /usr/local/lib/python3.7/dist-packages (from ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit==0.82->promptsource==0.2.3) (7.9.0)
# Requirement already satisfied: jupyter-client in /usr/local/lib/python3.7/dist-packages (from ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit==0.82->promptsource==0.2.3) (6.1.12)
# Requirement already satisfied: backcall in /usr/local/lib/python3.7/dist-packages (from ipython>=5.0.0->ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit==0.82->promptsource==0.2.3) (0.2.0)
# Requirement already satisfied: pexpect in /usr/local/lib/python3.7/dist-packages (from ipython>=5.0.0->ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit==0.82->promptsource==0.2.3) (4.8.0)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.7/dist-packages (from ipython>=5.0.0->ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit==0.82->promptsource==0.2.3) (57.4.0)
# Collecting jedi>=0.10
#   Downloading jedi-0.18.1-py2.py3-none-any.whl (1.6 MB)
#      |████████████████████████████████| 1.6 MB 51.9 MB/s
# Requirement already satisfied: decorator in /usr/local/lib/python3.7/dist-packages (from ipython>=5.0.0->ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit==0.82->promptsource==0.2.3) (4.4.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.7/dist-packages (from ipython>=5.0.0->ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit==0.82->promptsource==0.2.3) (0.7.5)
# Requirement already satisfied: prompt-toolkit<2.1.0,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from ipython>=5.0.0->ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit==0.82->promptsource==0.2.3) (2.0.10)
# Requirement already satisfied: pygments in /usr/local/lib/python3.7/dist-packages (from ipython>=5.0.0->ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit==0.82->promptsource==0.2.3) (2.6.1)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in /usr/local/lib/python3.7/dist-packages (from ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit==0.82->promptsource==0.2.3) (1.1.1)
# Requirement already satisfied: widgetsnbextension~=3.6.0 in /usr/local/lib/python3.7/dist-packages (from ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit==0.82->promptsource==0.2.3) (3.6.1)
# Requirement already satisfied: ipython-genutils~=0.2.0 in /usr/local/lib/python3.7/dist-packages (from ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit==0.82->promptsource==0.2.3) (0.2.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /usr/local/lib/python3.7/dist-packages (from jedi>=0.10->ipython>=5.0.0->ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit==0.82->promptsource==0.2.3) (0.8.3)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.7/dist-packages (from jinja2->promptsource==0.2.3) (2.0.1)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.7/dist-packages (from prompt-toolkit<2.1.0,>=2.0.0->ipython>=5.0.0->ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit==0.82->promptsource==0.2.3) (0.2.5)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->promptsource==0.2.3) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->promptsource==0.2.3) (2022.6.15)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->promptsource==0.2.3) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->promptsource==0.2.3) (3.0.4)
# Collecting urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1
#   Downloading urllib3-1.25.11-py2.py3-none-any.whl (127 kB)
#      |████████████████████████████████| 127 kB 59.7 MB/s
# Requirement already satisfied: notebook>=4.4.1 in /usr/local/lib/python3.7/dist-packages (from widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit==0.82->promptsource==0.2.3) (5.3.1)
# Requirement already satisfied: terminado>=0.8.1 in /usr/local/lib/python3.7/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit==0.82->promptsource==0.2.3) (0.13.3)
# Requirement already satisfied: Send2Trash in /usr/local/lib/python3.7/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit==0.82->promptsource==0.2.3) (1.8.0)
# Requirement already satisfied: jupyter-core>=4.4.0 in /usr/local/lib/python3.7/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit==0.82->promptsource==0.2.3) (4.11.1)
# Requirement already satisfied: nbconvert in /usr/local/lib/python3.7/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit==0.82->promptsource==0.2.3) (5.6.1)
# Requirement already satisfied: nbformat in /usr/local/lib/python3.7/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit==0.82->promptsource==0.2.3) (5.4.0)
# Requirement already satisfied: pyzmq>=13 in /usr/local/lib/python3.7/dist-packages (from jupyter-client->ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit==0.82->promptsource==0.2.3) (23.2.0)
# Requirement already satisfied: ptyprocess in /usr/local/lib/python3.7/dist-packages (from terminado>=0.8.1->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit==0.82->promptsource==0.2.3) (0.7.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets>=1.7.0->promptsource==0.2.3) (1.3.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets>=1.7.0->promptsource==0.2.3) (6.0.2)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets>=1.7.0->promptsource==0.2.3) (1.2.0)
# Requirement already satisfied: asynctest==0.13.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets>=1.7.0->promptsource==0.2.3) (0.13.0)
# Requirement already satisfied: charset-normalizer<3.0,>=2.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets>=1.7.0->promptsource==0.2.3) (2.1.0)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets>=1.7.0->promptsource==0.2.3) (4.0.2)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets>=1.7.0->promptsource==0.2.3) (1.8.1)
# Collecting pyflakes<2.6.0,>=2.5.0
#   Downloading pyflakes-2.5.0-py2.py3-none-any.whl (66 kB)
#      |████████████████████████████████| 66 kB 3.7 MB/s
# Collecting mccabe<0.8.0,>=0.7.0
#   Downloading mccabe-0.7.0-py2.py3-none-any.whl (7.3 kB)
# Collecting pycodestyle<2.10.0,>=2.9.0
#   Downloading pycodestyle-2.9.1-py2.py3-none-any.whl (41 kB)
#      |████████████████████████████████| 41 kB 462 kB/s
# Collecting importlib-metadata
#   Downloading importlib_metadata-4.2.0-py3-none-any.whl (16 kB)
# Collecting gitdb<5,>=4.0.1
#   Downloading gitdb-4.0.9-py3-none-any.whl (63 kB)
#      |████████████████████████████████| 63 kB 1.5 MB/s
# Collecting smmap<6,>=3.0.1
#   Downloading smmap-5.0.0-py3-none-any.whl (24 kB)
# Requirement already satisfied: defusedxml in /usr/local/lib/python3.7/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit==0.82->promptsource==0.2.3) (0.7.1)
# Requirement already satisfied: testpath in /usr/local/lib/python3.7/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit==0.82->promptsource==0.2.3) (0.6.0)
# Requirement already satisfied: mistune<2,>=0.8.1 in /usr/local/lib/python3.7/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit==0.82->promptsource==0.2.3) (0.8.4)
# Requirement already satisfied: pandocfilters>=1.4.1 in /usr/local/lib/python3.7/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit==0.82->promptsource==0.2.3) (1.5.0)
# Requirement already satisfied: bleach in /usr/local/lib/python3.7/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit==0.82->promptsource==0.2.3) (5.0.1)
# Requirement already satisfied: fastjsonschema in /usr/local/lib/python3.7/dist-packages (from nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit==0.82->promptsource==0.2.3) (2.16.1)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.7/dist-packages (from bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit==0.82->promptsource==0.2.3) (0.5.1)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.7/dist-packages (from plotly->promptsource==0.2.3) (8.0.1)
# Collecting pycryptodomex>=3.6.6
#   Downloading pycryptodomex-3.15.0-cp35-abi3-manylinux2010_x86_64.whl (2.3 MB)
#      |████████████████████████████████| 2.3 MB 46.5 MB/s
# Collecting brotli>=1.0.9
#   Downloading Brotli-1.0.9-cp37-cp37m-manylinux1_x86_64.whl (357 kB)
#      |████████████████████████████████| 357 kB 60.8 MB/s
# Collecting pybcj>=0.6.0
#   Downloading pybcj-1.0.1-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (50 kB)
#      |████████████████████████████████| 50 kB 7.3 MB/s
# Requirement already satisfied: psutil in /usr/local/lib/python3.7/dist-packages (from py7zr->promptsource==0.2.3) (5.4.8)
# Collecting pyppmd<0.19.0,>=0.18.1
#   Downloading pyppmd-0.18.3-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (138 kB)
#      |████████████████████████████████| 138 kB 49.5 MB/s
# Collecting multivolumefile>=0.2.3
#   Downloading multivolumefile-0.2.3-py3-none-any.whl (17 kB)
# Collecting texttable
#   Downloading texttable-1.6.4-py2.py3-none-any.whl (10 kB)
# Collecting inflate64>=0.3.0
#   Downloading inflate64-0.3.0-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (92 kB)
#      |████████████████████████████████| 92 kB 9.9 MB/s
# Collecting pyzstd>=0.14.4
#   Downloading pyzstd-0.15.3-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (379 kB)
#      |████████████████████████████████| 379 kB 59.1 MB/s
# Requirement already satisfied: more-itertools>=4.0.0 in /usr/local/lib/python3.7/dist-packages (from pytest->promptsource==0.2.3) (8.14.0)
# Requirement already satisfied: py>=1.5.0 in /usr/local/lib/python3.7/dist-packages (from pytest->promptsource==0.2.3) (1.11.0)
# Requirement already satisfied: atomicwrites>=1.0 in /usr/local/lib/python3.7/dist-packages (from pytest->promptsource==0.2.3) (1.4.1)
# Requirement already satisfied: pluggy<0.8,>=0.5 in /usr/local/lib/python3.7/dist-packages (from pytest->promptsource==0.2.3) (0.7.1)
# Building wheels for collected packages: validators
#   Building wheel for validators (setup.py) ... done
#   Created wheel for validators: filename=validators-0.20.0-py3-none-any.whl size=19582 sha256=ee690504d1615c3f24cccf2fb8808bc556b56215928b3be9af7912c38a51b524
#   Stored in directory: /root/.cache/pip/wheels/5f/55/ab/36a76989f7f88d9ca7b1f68da6d94252bb6a8d6ad4f18e04e9
# Successfully built validators
# Installing collected packages: importlib-metadata, jedi, urllib3, smmap, pyyaml, gitdb, fsspec, xxhash, watchdog, validators, typed-ast, tomli, texttable, responses, pyzstd, pyppmd, pyflakes, pydeck, pycryptodomex, pycodestyle, pybcj, platformdirs, pathspec, mypy-extensions, multivolumefile, multiprocess, mccabe, inflate64, huggingface-hub, gitpython, brotli, blinker, base58, streamlit, py7zr, isort, flake8, datasets, black, promptsource
#   Attempting uninstall: importlib-metadata
#     Found existing installation: importlib-metadata 4.12.0
#     Uninstalling importlib-metadata-4.12.0:
#       Successfully uninstalled importlib-metadata-4.12.0
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 1.24.3
#     Uninstalling urllib3-1.24.3:
#       Successfully uninstalled urllib3-1.24.3
#   Attempting uninstall: pyyaml
#     Found existing installation: PyYAML 3.13
#     Uninstalling PyYAML-3.13:
#       Successfully uninstalled PyYAML-3.13
#   Attempting uninstall: tomli
#     Found existing installation: tomli 2.0.1
#     Uninstalling tomli-2.0.1:
#       Successfully uninstalled tomli-2.0.1
#   Running setup.py develop for promptsource
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# markdown 3.4.1 requires importlib-metadata>=4.4; python_version < "3.10", but you have importlib-metadata 4.2.0 which is incompatible.
# Successfully installed base58-2.1.1 black-21.12b0 blinker-1.5 brotli-1.0.9 datasets-2.4.0 flake8-5.0.4 fsspec-2022.7.1 gitdb-4.0.9 gitpython-3.1.27 huggingface-hub-0.8.1 importlib-metadata-4.2.0 inflate64-0.3.0 isort-5.8.0 jedi-0.18.1 mccabe-0.7.0 multiprocess-0.70.13 multivolumefile-0.2.3 mypy-extensions-0.4.3 pathspec-0.9.0 platformdirs-2.5.2 promptsource-0.2.3 py7zr-0.20.0 pybcj-1.0.1 pycodestyle-2.9.1 pycryptodomex-3.15.0 pydeck-0.7.1 pyflakes-2.5.0 pyppmd-0.18.3 pyyaml-6.0 pyzstd-0.15.3 responses-0.18.0 smmap-5.0.0 streamlit-0.82.0 texttable-1.6.4 tomli-1.2.3 typed-ast-1.5.4 urllib3-1.25.11 validators-0.20.0 watchdog-2.1.9 xxhash-3.0.0

# %%
# !pip install datasets
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: datasets in /usr/local/lib/python3.7/dist-packages (2.4.0)
# Requirement already satisfied: pandas in /usr/local/lib/python3.7/dist-packages (from datasets) (1.3.5)
# Requirement already satisfied: responses<0.19 in /usr/local/lib/python3.7/dist-packages (from datasets) (0.18.0)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.7/dist-packages (from datasets) (2.23.0)
# Requirement already satisfied: dill<0.3.6 in /usr/local/lib/python3.7/dist-packages (from datasets) (0.3.5.1)
# Requirement already satisfied: tqdm>=4.62.1 in /usr/local/lib/python3.7/dist-packages (from datasets) (4.64.0)
# Requirement already satisfied: huggingface-hub<1.0.0,>=0.1.0 in /usr/local/lib/python3.7/dist-packages (from datasets) (0.8.1)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.7/dist-packages (from datasets) (3.0.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.7/dist-packages (from datasets) (1.21.6)
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/dist-packages (from datasets) (21.3)
# Requirement already satisfied: fsspec[http]>=2021.11.1 in /usr/local/lib/python3.7/dist-packages (from datasets) (2022.7.1)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.7/dist-packages (from datasets) (3.8.1)
# Requirement already satisfied: pyarrow>=6.0.0 in /usr/local/lib/python3.7/dist-packages (from datasets) (6.0.1)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from datasets) (4.2.0)
# Requirement already satisfied: multiprocess in /usr/local/lib/python3.7/dist-packages (from datasets) (0.70.13)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.7/dist-packages (from huggingface-hub<1.0.0,>=0.1.0->datasets) (6.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.7/dist-packages (from huggingface-hub<1.0.0,>=0.1.0->datasets) (4.1.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from huggingface-hub<1.0.0,>=0.1.0->datasets) (3.8.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging->datasets) (3.0.9)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->datasets) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->datasets) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->datasets) (1.25.11)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->datasets) (2022.6.15)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets) (22.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets) (1.3.1)
# Requirement already satisfied: charset-normalizer<3.0,>=2.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets) (2.1.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets) (6.0.2)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets) (4.0.2)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets) (1.2.0)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets) (1.8.1)
# Requirement already satisfied: asynctest==0.13.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets) (0.13.0)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->datasets) (3.8.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas->datasets) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas->datasets) (2022.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas->datasets) (1.15.0)

# %%
# Load an example from the datasets ag_news
from datasets import load_dataset
dataset = load_dataset("ag_news", split="train")
example = dataset[1]
# Out:
# Downloading builder script:   0%|          | 0.00/1.83k [00:00<?, ?B/s]
# Downloading metadata:   0%|          | 0.00/1.28k [00:00<?, ?B/s]
# WARNING:datasets.builder:Using custom data configuration default
# Downloading and preparing dataset ag_news/default (download: 29.88 MiB, generated: 30.23 MiB, post-processed: Unknown size, total: 60.10 MiB) to /root/.cache/huggingface/datasets/ag_news/default/0.0.0/bc2bcb40336ace1a0374767fc29bb0296cdaf8a6da7298436239c54d79180548...
# Downloading data:   0%|          | 0.00/11.0M [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/751k [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/120000 [00:00<?, ? examples/s]
# Generating test split:   0%|          | 0/7600 [00:00<?, ? examples/s]
# Dataset ag_news downloaded and prepared to /root/.cache/huggingface/datasets/ag_news/default/0.0.0/bc2bcb40336ace1a0374767fc29bb0296cdaf8a6da7298436239c54d79180548. Subsequent calls will reuse this data.

# %%
print(example)
# Out:
# {'text': 'Carlyle Looks Toward Commercial Aerospace (Reuters) Reuters - Private investment firm Carlyle Group,\\which has a reputation for making well-timed and occasionally\\controversial plays in the defense industry, has quietly placed\\its bets on another part of the market.', 'label': 2}

# %%
# Load prompts for this dataset
from promptsource.templates import DatasetTemplates
ag_news_prompts = DatasetTemplates('ag_news')

# %%
print(ag_news_prompts)
# Out:
# <promptsource.templates.DatasetTemplates object at 0x7fe6d8666290>

# %%
# Print all the prompts available for this dataset. The keys of the dict are the uuids the uniquely identify each of the prompt, and the values are instances of `Template` which wraps prompts
print(ag_news_prompts.templates)
# Out:
# {'24e44a81-a18a-42dd-a71c-5b31b2d2cb39': <promptsource.templates.Template object at 0x7fe6d3b91150>, '8fdc1056-1029-41a1-9c67-354fc2b8ceaf': <promptsource.templates.Template object at 0x7fe6d3b8abd0>, '918267e0-af68-4117-892d-2dbe66a58ce9': <promptsource.templates.Template object at 0x7fe6d3b8a910>, '9345df33-4f23-4944-a33c-eef94e626862': <promptsource.templates.Template object at 0x7fe6d3b7ae90>, '98534347-fff7-4c39-a795-4e69a44791f7': <promptsource.templates.Template object at 0x7fe6d3b7aed0>, 'b401b0ee-6ffe-4a91-8e15-77ee073cd858': <promptsource.templates.Template object at 0x7fe6d3b7ac90>, 'cb355f33-7e8c-4455-a72b-48d315bd4f60': <promptsource.templates.Template object at 0x7fe6d3b7af10>}

# %%
# Select a prompt by its name
prompt = ag_news_prompts["classify_question_first"]

# %%
# Apply the prompt to the example
result = prompt.apply(example)
print("INPUT:", result[0])
print("TARGET:", result[1])
# Out:
# INPUT: What label best describes this news article?
# Carlyle Looks Toward Commercial Aerospace (Reuters) Reuters - Private investment firm Carlyle Group,\which has a reputation for making well-timed and occasionally\controversial plays in the defense industry, has quietly placed\its bets on another part of the market.
# TARGET: Business

# %% [markdown]
# To launch the app locally, please first make sure you have followed the steps in Setup, and from the root directory of the repo, run:

# %%
# !ngrok_token=2DRTCgCAy1e5TcCyIgZSvi58atk_7JvofUs4GEpMXYDojbHvF

# %%
# !chmod +x ngrok

# %%
# !./ngrok authtoken 2DRTCgCAy1e5TcCyIgZSvi58atk_7JvofUs4GEpMXYDojbHvF
# Out:
# Authtoken saved to configuration file: /root/.ngrok2/ngrok.yml

# %%
# !pip install pyngrok
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting pyngrok
#   Downloading pyngrok-5.1.0.tar.gz (745 kB)
#      |████████████████████████████████| 745 kB 5.3 MB/s
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.7/dist-packages (from pyngrok) (6.0)
# Building wheels for collected packages: pyngrok
#   Building wheel for pyngrok (setup.py) ... done
#   Created wheel for pyngrok: filename=pyngrok-5.1.0-py3-none-any.whl size=19007 sha256=a826290f9c4ce03b3c3f0f7fa72a6c488e1763a675da2cedb79fd24cda807387
#   Stored in directory: /root/.cache/pip/wheels/bf/e6/af/ccf6598ecefecd44104069371795cb9b3afbcd16987f6ccfb3
# Successfully built pyngrok
# Installing collected packages: pyngrok
# Successfully installed pyngrok-5.1.0

# %%
# !streamlit run promptsource/app.py & npx localtunnel --port 8501
# Out:
# 2022-08-16 14:48:37.501 INFO    numexpr.utils: NumExpr defaulting to 2 threads.
# npx: installed 22 in 2.73s
#
#   You can now view your Streamlit app in your browser.
#
#   Network URL: http://172.28.0.2:8501
#   External URL: http://35.231.71.147:8501
#
# your url is: https://every-women-eat-35-231-71-147.loca.lt
#   Stopping...
# ^C
