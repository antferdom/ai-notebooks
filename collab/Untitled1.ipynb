# %%
import numpy as np

n = 200                          # number of instances
d = 764                          # number of instance features
n_neurons = 100                  # how many neurons in this layer?

W = np.random.rand(d,n_neurons)  # Ooops! Should be (n_neurons,d) <=======
b = np.random.rand(n_neurons,1)
X = np.random.rand(n,d)          # fake input matrix with n rows of d-dimensions

Y = W @ X.T + b                  # pass all X instances through layer
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-1-655f9bcb5b57> in <module>()
#       9 X = np.random.rand(n,d)          # fake input matrix with n rows of d-dimensions
#      10
# ---> 11 Y = W @ X.T + b                  # pass all X instances through layer
#
# ValueError: matmul: Input operand 1 has a mismatch in its core dimension 0, with gufunc signature (n?,k),(k,m?)->(n?,m?) (size 764 is different from 100)

# %%
# !pip install tsensor
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ERROR: Could not find a version that satisfies the requirement tsensor (from versions: none)
# ERROR: No matching distribution found for tsensor

# %%
import tsensor
with tsensor.clarify():
    Y = W @ X.T + b
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-2-d9c2549ab0a5> in <module>()
# ----> 1 import tsensor
#       2 with tsensor.clarify():
#       3     Y = W @ X.T + b
#
# ModuleNotFoundError: No module named 'tsensor'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------
