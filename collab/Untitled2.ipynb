# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/github/soft-prompt-tuning
# Out:
# /content/drive/MyDrive/github/soft-prompt-tuning
