# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd ./drive/MyDrive/github
# Out:
# /content/drive/MyDrive/github

# %%
# !git clone https://github.com/EleutherAI/github-downloader.git
# Out:
# Cloning into 'github-downloader'...
# remote: Enumerating objects: 203, done.
# remote: Total 203 (delta 0), reused 0 (delta 0), pack-reused 203
# Receiving objects: 100% (203/203), 4.83 MiB | 11.21 MiB/s, done.
# Resolving deltas: 100% (122/122), done.
